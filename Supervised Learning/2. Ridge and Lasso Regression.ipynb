# %% [raw]
# Agenda
#
# Linear regression is foundation of these Algorithm.
# Linear Regression Algorithm focuses on best fit in order to be best fit sometimes it overfits itself In that case we use
# Ridge and Lasso Alogrithm
#
# Overfit Error --> Test Maz Maximum Error
#
# Simply we Generalize the Linear Regression Model using Lasso and Ridge.

# %% [raw]
# Lasso Refression
#
#     We find cost function from Linear regression Model
#
#     Cost function = (Actual value - Pridicted Value)**2 + (alpha) magnitude of the slope
#         bydefault alpha = 1
#
#     Mostly we try that model's cost function value stay 0

# %% [raw]
# Ridge Refression
#
#     We find cost function from Linear regression Model
#     Cost function = (Actual value - Pridicted Value)**2 + (alpha) (magnitude of the slope)**2
#         bydefault alpha = 1
#
#     Mostly we try that model's cost function value stay 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso,Ridge

# %%
# Loading Dataset
df = pd.read_csv(r"D:\bangalore house price prediction OHE-data.csv")
df.head()
# Out:
#    bath  balcony  price  ...  location_Domlur  location_Mahadevpura  location_Tumkur Road
# 0   3.0      2.0  150.0  ...                0                     0                     0
# 1   3.0      3.0  149.0  ...                0                     0                     0
# 2   3.0      2.0  150.0  ...                0                     0                     0
# 3   2.0      2.0   40.0  ...                0                     0                     0
# 4   2.0      2.0   83.0  ...                0                     0                     0
#
# [5 rows x 108 columns]

# %%
# spliting dataset in independent and dependent variable 

X = df.drop(["price"],axis = 1)
y = df["price"]

# %%
print("Shape of X ",X.shape)
print("Shape of y ",y.shape)
# Out:
# Shape of X  (7120, 107)
# Shape of y  (7120,)

# %%
# training and testing

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 51)

print("Shape of X_train ",X_train.shape)
print("Shape of y_train ",y_train.shape)
print("Shape of X_test ",X_test.shape)
print("Shape of y_test ",y_test.shape)
# Out:
# Shape of X_train  (5696, 107)
# Shape of y_train  (5696,)
# Shape of X_test  (1424, 107)
# Shape of y_test  (1424,)

# %%
X_train
# Out:
#       bath  balcony  total_sqft_int  ...  location_Domlur  location_Mahadevpura  location_Tumkur Road
# 7112   5.0      2.0          2500.0  ...                0                     0                     0
# 2169   2.0      0.0           995.0  ...                0                     0                     0
# 47     2.0      2.0          1180.0  ...                0                     0                     0
# 446    2.0      1.0          1450.0  ...                0                     0                     0
# 2650   2.0      1.0          1197.0  ...                0                     0                     0
# ...    ...      ...             ...  ...              ...                   ...                   ...
# 6672   2.0      1.0          1246.0  ...                0                     0                     0
# 1733   2.0      1.0          1010.0  ...                0                     0                     0
# ...

# %%
# We have to use feature scaling
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
# Linear Regression

lr = LinearRegression()
lr.fit(X_train,y_train)  # it is supervised Learning so that we have give both input and output
# Out:
# LinearRegression()

# %%
lr.predict([X_test[0,:]])
# Out:
# array([76.90661876])

# %%
# accuracy 
lr.score(X_test,y_test)
# Out:
# 0.7903837092682252

# %%
# Ridge Regression

rd = Ridge()

rd.fit(X_train,y_train)
rd.score(X_test,y_test)  # accuracy improved by 0.0002
# Out:
# 0.7905686374336621

# %%
# Lasso 
ls = Lasso()
ls.fit(X_train,y_train)
ls.score(X_test,y_test)   # accuracy improved
# Out:
# 0.8036373003525774

# %%
# Now Changing the value of alpha

# Ridge Regression

rd2 = Ridge(alpha=2)

rd2.fit(X_train,y_train)
rd2.score(X_test,y_test)
# Out:
# 0.790753026039793

# %%
# Lasso 
ls2 = Lasso(alpha = 2)
ls2.fit(X_train,y_train)
ls2.score(X_test,y_test)   # accuracy improved
# Out:
# 0.8160181533703601

# %%
# Lasso 
ls3 = Lasso(alpha = 3)
ls3.fit(X_train,y_train)
ls3.score(X_test,y_test)   # accuracy improved
# Out:
# 0.8263450613017427

# %%
# instead of filling value manually fill value with hyperparameter tuning
