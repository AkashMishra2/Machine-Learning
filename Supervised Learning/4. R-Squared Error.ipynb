# %% [raw]
# Agenda
#
# What is Residual ??
# What is R-Squared ??
# Formula
# What is goodness of fit ??
# Best R-sqrt score
# Practical

# %% [markdown]
# Residual ??
#
# distance between model and outlier value is residual(Error)
#
# Residual = Actual value(observed value) - pridicte value
#
# NOTE
#     Residual max means worst Model
#     Residual min means best Model

# %% [raw]
# R-Squared ??
#
# is statistical measure of how close the data are to the fitted(pridicted) regression line.
# it is also known as the coefficient of determination, or the coefficient of multiple determination for multiple regression.
#
# we get value 0-1
#     0 or negative is worst value(0%)
#     1 is best value (100%)
#
# (R)sqr = 1-(SSres/SStot) = 1-(Semmesion((y1-y2)**2 / Semmesion((y1-y3)**2)
#             SS => sum of square
#             y3 => mean

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r"D:\bangalore house price prediction OHE-data.csv")
df.head()
# Out:
#    bath  balcony  price  ...  location_Domlur  location_Mahadevpura  location_Tumkur Road
# 0   3.0      2.0  150.0  ...                0                     0                     0
# 1   3.0      3.0  149.0  ...                0                     0                     0
# 2   3.0      2.0  150.0  ...                0                     0                     0
# 3   2.0      2.0   40.0  ...                0                     0                     0
# 4   2.0      2.0   83.0  ...                0                     0                     0
#
# [5 rows x 108 columns]

# %%
# Spliting dataset
X = df.drop(["price"],axis = 1)
y = df["price"]

# %%
print("Shape of DataFrame : ",df.shape)
print("Shape of X : ",X.shape)
print("Shape of y : ",y.shape)
# Out:
# Shape of DataFrame :  (7120, 108)
# Shape of X :  (7120, 107)
# Shape of y :  (7120,)

# %%
# train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 51)

# %%
print("Shape of X_train : ",X_train.shape)
print("Shape of y_train : ",y_train.shape)
print("Shape of X_test : ",X_test.shape)
print("Shape of y_test : ",y_test.shape)
# Out:
# Shape of X_train :  (5696, 107)
# Shape of y_train :  (5696,)
# Shape of X_test :  (1424, 107)
# Shape of y_test :  (1424,)

# %%
# StandardScaler

sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
# Linear Regression
lr = LinearRegression() 
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([X_test[0,:]])
# Out:
# array([76.90661876])

# %%
lr.score(X_test,y_test)
# Out:
# 0.7903837092682252

# %%
y_pred = lr.predict(X_test)

# %% [markdown]
# # R-Square

# %%
r2_score(y_test,y_pred) # model give use near about 80% of accuracy
# Out:
# 0.7903837092682252
